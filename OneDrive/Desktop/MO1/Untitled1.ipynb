# %%
import pandas as pd

# %%
df = pd.read_excel("1.xlsx")

# %%
df.dtypes
# Out:
# ID операции              int64
# Дата            datetime64[ns]
# ID машины                int64
# ID дилера               object
# Количество               int64
# Тип операции            object
# dtype: object

# %%
df.columns
# Out:
# Index(['ID операции', 'Дата', 'ID машины', 'ID дилера', 'Количество',
#        'Тип операции'],
#       dtype='object')

# %%
df.loc[2]
# Out:
# ID операции                       3
# Дата            2018-01-03 00:00:00
# ID машины                        41
# ID дилера                       Д15
# Количество                       42
# Тип операции      Отдано покупателю
# Name: 2, dtype: object

# %%
df.loc[2:4]
# Out:
#    ID операции       Дата  ID машины ID дилера  Количество       Тип операции
# 2            3 2018-01-03         41       Д15          42  Отдано покупателю
# 3            4 2018-01-04         59        Д9          44   Поступило дилеру
# 4            5 2018-01-05         39       Д16          24  Отдано покупателю

# %%
subdf = df.sample(5)

# %%
subdf.iloc[2:4]
# Out:
#      ID операции       Дата  ID машины ID дилера  Количество      Тип операции
# 312          313 2018-11-09          4        Д6          17  Поступило дилеру
# 662          663 2019-10-25         30        Д3          36  Поступило дилеру

# %%
df.head(None)
# Out:
#       ID операции       Дата  ID машины ID дилера  Количество  \
# 0               1 2018-01-01         32        Д5          51
# 1               2 2018-01-02         43        Д9          45
# 2               3 2018-01-03         41       Д15          42
# 3               4 2018-01-04         59        Д9          44
# 4               5 2018-01-05         39       Д16          24
# ...           ...        ...        ...       ...         ...
# 1821         1822 2022-12-27         37        Д6          16
# 1822         1823 2022-12-28         50        Д9          33
# 1823         1824 2022-12-29         46       Д12          52
# 1824         1825 2022-12-30         41        Д4          35
# 1825         1826 2022-12-31         36        Д8          22
#
#            Тип операции
# 0      Поступило дилеру
# 1      Поступило дилеру
# 2     Отдано покупателю
# 3      Поступило дилеру
# 4     Отдано покупателю
# ...                 ...
# 1821   Поступило дилеру
# ...

# %%
df[df['ID машины'] == 43]
# Out:
#       ID операции       Дата  ID машины ID дилера  Количество  \
# 1               2 2018-01-02         43        Д9          45
# 15             16 2018-01-16         43       Д10          14
# 33             34 2018-02-03         43        Д1          21
# 66             67 2018-03-08         43        Д9          19
# 70             71 2018-03-12         43        Д6           5
# 80             81 2018-03-22         43       Д10          55
# 88             89 2018-03-30         43        Д7           7
# 195           196 2018-07-15         43        Д9          32
# 256           257 2018-09-14         43       Д11           8
# 278           279 2018-10-06         43        Д1          43
# 291           292 2018-10-19         43        Д1          29
# 303           304 2018-10-31         43       Д11          11
# 322           323 2018-11-19         43        Д4          31
# 399           400 2019-02-04         43        Д9           7
# ...

# %%
df.isna().sum()
# Out:
# ID операции     0
# Дата            0
# ID машины       0
# ID дилера       0
# Количество      0
# Тип операции    0
# dtype: int64

# %%
# Out:
#            ID операции  Дата  ID дилера  Количество  Тип операции
# ID машины
# 1                   29    29         29          29            29
# 2                   25    25         25          25            25
# 3                   29    29         29          29            29
# 4                   31    31         31          31            31
# 5                   33    33         33          33            33
# ...                ...   ...        ...         ...           ...
# 60                  33    33         33          33            33
# 61                  22    22         22          22            22
# 62                  24    24         24          24            24
# 63                  31    31         31          31            31
# 64                  24    24         24          24            24
#
# [64 rows x 5 columns]

# %%
df.describe()
# Out:
#        ID операции    ID машины   Количество
# count  1826.000000  1826.000000  1826.000000
# mean    913.500000    32.218510    30.312158
# std     527.265114    18.316963    17.031511
# min       1.000000     1.000000     1.000000
# 25%     457.250000    17.000000    16.000000
# 50%     913.500000    32.000000    30.000000
# 75%    1369.750000    48.000000    45.000000
# max    1826.000000    64.000000    60.000000

# %%
display(df['ID машины'].nunique())
len(df['ID машины'])
# Out:
# 64
# 1826

# %%
df.count()
# Out:
# ID операции     1826
# Дата            1826
# ID машины       1826
# ID дилера       1826
# Количество      1826
# Тип операции    1826
# dtype: int64
